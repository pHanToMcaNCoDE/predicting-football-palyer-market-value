# %%
import pandas as pd

# %%
url = "https://www.transfermarkt.com/premier-league/marktwerteverein/wettbewerb/GB1"

tables = pd.read_html(url)

print(len(tables))
# Out:
# 14

# %%
for i, table in enumerate(tables):
    print(f"\nTABLE {i}")
    print(table.head())
# Out:
# TABLE 0
#                0                                                  1   2
# 0  Cut-off date:  01/06/2026  15/05/2026  01/05/2026  15/04/2026... NaN
#
# TABLE 1
#      #  wappen               Club          Club.1    League Value 15/05/2026  \
# 0  1.0     NaN    Manchester City  Premier League   €1.31bn          €1.32bn
# 1  2.0     NaN         Arsenal FC  Premier League   €1.23bn          €1.23bn
# 2  3.0     NaN         Chelsea FC  Premier League   €1.16bn          €1.16bn
# 3  4.0     NaN       Liverpool FC  Premier League   €1.02bn          €1.02bn
# 4  5.0     NaN  Tottenham Hotspur  Premier League  €802.50m         €811.00m
#
#   Current value    % Unnamed: 8 Unnamed: 9
# 0         0.2 %  NaN        NaN        NaN
# 1             -  NaN        NaN        NaN
# 2             -  NaN        NaN        NaN
# 3             -  NaN        NaN        NaN
# 4         1.1 %  NaN        NaN        NaN
#
# TABLE 2
#      #                     Player  Club Market value
# 0  1.0  William SalibaCentre-Back   NaN      €90.00m
# 1  NaN             William Saliba   NaN          NaN
# 2  NaN                Centre-Back   NaN          NaN
# 3  2.0         GabrielCentre-Back   NaN      €75.00m
# 4  NaN                    Gabriel   NaN          NaN
#
# TABLE 3
#     0               1
# 0 NaN  William Saliba
# 1 NaN     Centre-Back
#
# TABLE 4
#     0            1
# 0 NaN      Gabriel
# 1 NaN  Centre-Back
#
# TABLE 5
#     0               1
# 0 NaN  Josko Gvardiol
# 1 NaN     Centre-Back
#
# TABLE 6
#     0            1
# 0 NaN   Marc Guéhi
# 1 NaN  Centre-Back
#
# TABLE 7
#     0                 1
# 0 NaN  Micky van de Ven
# 1 NaN       Centre-Back
#
# TABLE 8
#      #                           Player  Club Market value
# 0  1.0         Carl RushworthGoalkeeper   NaN      €16.00m
# 1  NaN                   Carl Rushworth   NaN          NaN
# 2  NaN                       Goalkeeper   NaN          NaN
# 3  2.0  Malick YalcouyéCentral Midfield   NaN      €12.00m
# 4  NaN                  Malick Yalcouyé   NaN          NaN
#
# TABLE 9
#     0               1
# 0 NaN  Carl Rushworth
# 1 NaN      Goalkeeper
#
# TABLE 10
#     0                 1
# 0 NaN   Malick Yalcouyé
# 1 NaN  Central Midfield
#
# TABLE 11
#     0             1
# 0 NaN   Romain Esse
# 1 NaN  Right Winger
#
# TABLE 12
#     0                 1
# 0 NaN      Frank Onyeka
# 1 NaN  Central Midfield
#
# TABLE 13
#     0                 1
# 0 NaN       Tommy Doyle
# 1 NaN  Central Midfield

# %%
market_values = tables[2]

market_values.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   #             5 non-null      float64
#  1   Player        15 non-null     object
#  2   Club          0 non-null      float64
#  3   Market value  5 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 612.0+ bytes

# %%
market_values.head(20)
# Out:
#       #                       Player  Club Market value
# 0   1.0    William SalibaCentre-Back   NaN      €90.00m
# 1   NaN               William Saliba   NaN          NaN
# 2   NaN                  Centre-Back   NaN          NaN
# 3   2.0           GabrielCentre-Back   NaN      €75.00m
# 4   NaN                      Gabriel   NaN          NaN
# 5   NaN                  Centre-Back   NaN          NaN
# 6   3.0    Josko GvardiolCentre-Back   NaN      €70.00m
# 7   NaN               Josko Gvardiol   NaN          NaN
# 8   NaN                  Centre-Back   NaN          NaN
# 9   4.0        Marc GuéhiCentre-Back   NaN      €65.00m
# 10  NaN                   Marc Guéhi   NaN          NaN
# 11  NaN                  Centre-Back   NaN          NaN
# 12  5.0  Micky van de VenCentre-Back   NaN      €65.00m
# 13  NaN             Micky van de Ven   NaN          NaN
# 14  NaN                  Centre-Back   NaN          NaN

# %%
for i in range(14):
    print(f"\nTABLE {i}")
    print(tables[i].shape)
# Out:
# TABLE 0
# (1, 3)
#
# TABLE 1
# (21, 10)
#
# TABLE 2
# (15, 4)
#
# TABLE 3
# (2, 2)
#
# TABLE 4
# (2, 2)
#
# TABLE 5
# (2, 2)
#
# TABLE 6
# (2, 2)
#
# TABLE 7
# (2, 2)
#
# TABLE 8
# (15, 4)
#
# TABLE 9
# (2, 2)
#
# TABLE 10
# (2, 2)
#
# TABLE 11
# (2, 2)
#
# TABLE 12
# (2, 2)
#
# TABLE 13
# (2, 2)
